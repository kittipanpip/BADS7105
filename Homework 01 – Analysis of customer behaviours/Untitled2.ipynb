# %% [markdown]
# Analysis of customer behaviours

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('ticks')

import warnings
warnings.filterwarnings('ignore')

# %%
survey_data = pd.read_excel('BADS7105/Customer Behaviors (Responses).xlsx')
survey_data.head()
# Out:
#                 Timestamp  ...   เพศ
# 0 2021-01-09 10:07:27.365  ...   ชาย
# 1 2021-01-09 10:07:34.010  ...  หญิง
# 2 2021-01-09 10:07:35.902  ...   ชาย
# 3 2021-01-09 10:07:36.476  ...   ชาย
# 4 2021-01-09 10:07:41.965  ...  หญิง
#
# [5 rows x 64 columns]
