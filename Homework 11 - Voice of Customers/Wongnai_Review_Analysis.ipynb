# %% [markdown]
# ## **Load libraries and data**

# %%
# !pip install --upgrade pythainlp
# !pip install pyLDAvis
# !pip install emoji
# Out:
# Requirement already up-to-date: pythainlp in /usr/local/lib/python3.7/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: tinydb>=3.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (4.4.0)
# Requirement already satisfied, skipping upgrade: python-crfsuite>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (0.9.7)
# Requirement already satisfied, skipping upgrade: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (2.23.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2021.5.30)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.22.2.post1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.0.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.20.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.2.4)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (1.2.0)

# %%
import pandas as pd
import string
import emoji
import re
import pythainlp
from nltk.tokenize import RegexpTokenizer
from pythainlp.corpus.common import thai_words
from pythainlp import Tokenizer, word_tokenize
from pythainlp.util import normalize
from pythainlp import correct
import gensim
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
df = pd.read_csv('CustomerReviews.csv')

# %%
df.tail()
# Out:
#     Review ID  ... Rating
# 16         17  ...    4.0
# 17         18  ...    4.0
# 18         19  ...    3.0
# 19         20  ...    5.0
# 20         21  ...    NaN
#
# [5 rows x 7 columns]

# %% [markdown]
# ## **Tokenize Words**

# %%
stopwords = list(pythainlp.corpus.thai_stopwords())
punctuations = list(string.punctuation)
removed_words = [' ', '  ', '\n', 'ร้าน', '(', ')' , '           ', '!!!!', '++', '..', './', '::', '^^','xx','-']
"""'\u200b',':','-' """

screening_words = stopwords + removed_words +punctuations

"""
words = set(thai_words())  
words.add("ชาบูชิ") 
custom_tokenizer = Tokenizer(words)
print("custom dictionary :", custom_tokenizer.word_tokenize(text))
"""

def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)



def tokenize_with_space(sentence):
  sentence = re.sub(r'\d+', '', sentence)
  sentence = deEmojify(sentence)
  merged = ''
  words = word_tokenize(normalize(str(sentence)), engine="multi_cut", keep_whitespace=False)
  for word in words:
    #print(word)
    if word not in screening_words:
      merged = merged + ',' + word
  return merged[1:]

# %%
df['Review_tokenized'] = df['Review'].apply(lambda x: tokenize_with_space(x))

# %%
df.tail()
# Out:
#     Review ID  ...                                   Review_tokenized
# 16         17  ...  หลังจากที่,เคยลอง,สาขายู,นม,อลล์,รอบนี้,สาขา,เ...
# 17         18  ...  ร้านบุฟเฟ่ต์,โปรโมชั่น,หัว,บาท,น้ำ,VAT,ทานวัน,...
# 18         19  ...  รู้จักร้าน,union,mall,ลอง,กิน,จำได้,ขึ้นใจ,จาก...
# 19         20  ...  อร่อย,มากค่ะ,คุ้มค่า,สมราคา,บุ,ฟเฟ่,หมู,ผัก,น้...
# 20         21  ...  ก็ตามที่,จ่าย,ราคา,บาท,จ่าย,เงินสดนะ,ราคานี้,น...
#
# [5 rows x 8 columns]

# %%
for index, row in df.iterrows():
    print(" index {} \n Review {} \n".format(index+1,row['Review']))
# Out:
#  index 1
#  Review ที่สำคัญของร้านนี้คือบริการดีมากพนักงานน่ารักสุดๆสะอาดสะอ้านใส่ใจค่อนข้างประทับใจกับการบริการรสชาติอาหารอันนี้แปลก​ใหม่
# เซ็ท560 บาท
# อาหารจำกัด​ไม่ได้​หลากหลาย​แต่เพียง​พอกับความต้องการ
# เราไม่กินเนื้อ​ กินสันคอ4 ถาด​ เป็ด1
# แฟนกินเนื้อ​ คุณ​ภาพ​ดี
# น้ำซุป​ดำ​กับเผ็ด
# ที่สำคัญคือน้ำจิ้มอร่อยมากไม่เคยกินรสชาติแบบนี้มาก่อนเป็นเต้าเจี้ยวนิดๆแต่ก็ไม่ได้เคลมก็รสชาติดีนะถามราคาโดยรวมก็ถือว่าคุ้มเพราะว่าโมจิอร่อยมากไอติมก็อร่อยไม่ต้องออกไปกินข้างนอกสรุปรวมๆละกันว่าประทับใจในบริการและคุณภาพของอาหาร
#
#  index 2
#  Review นึกถึงชาบูญี่ปุ่นยังไงก็ต้อง คิดถึงโมโม่ พาราไดซ์ คุณภาพเค้ามาตราฐานจริงๆ วันนี้มีโอกาสมาทานก่อนร้านปิด 30 นาที ทางร้านก็บริการดี จะมีก็แต่อาหาร เครื่องดื่มที่ทางร้านเริ่มทะยอยเก็บ แต่เราก็เข้าใจเพราะทางร้านแจ้งรายละเอียดการงดรับออร์เดอร์แล้ว
#            สาขานี้ พนักงานบริการดี น่ารักเป็นกันเอง ขออะไรก็ได้หมด ไม่มีเหวี่ยง เคยเจอสาขา พระราม 9 คือ ไม่โอเค พนักงาน ไม่พร้อมทำงานมาก CTW แม้จะเป็นพรีเมียมการบริการก็สู้สาขานี้ไม่ได้ Terminal 21 ลูกค้าเยอะ
#
#  index 3
#  Review มาทานช่วงนี้ สามารถนั่งโต๊ะเดียวกัน หม้อเดียวกันได้แล้ว แต่ระหว่างโต๊ะยังมีฉากกั้นอยู่
#
# น้ำซุปเลือกได้ 2 รส น้ำจิ้มก็จะแตกต่างกันตามน้ำซุป เลือกมาเป็นชาบูน้ำดำ กับน้ำซุปเห็ด
# ชาบูน้ำดำ : หวานๆเค็มๆ รสชาติเข้มข้น เสิร์ฟพร้อมไข่สด ถ้าเป็นผู้ใหญ่ที่ไม่ชอบหวานๆ อาจจะไม่ค่อยชอบ
# น้ำซุปเห็ด : มีชื่อด้วยเป็นภาษาญี่ปุ่น แต่จำไม่ได้555 เสิร์ฟมากับ เห็ด และ น้ำจิ้มซอยซอส รสชาติจืดๆ แนวน้ำซุปใส
#
# เนื้อสัตว์จะมีให้เลือก เนื้อวัว 2 แบบ, เนื้อหมู 2 แบบ, เนื้อเป็ด, ไก่ไม้ไผ่ เลยสั่งมาลองทุกอย่าง
# เนื้อวัว : อร่อยมากก ชิ้นไม่บาง เนื้อนุ่มมากๆ กินกับชาบูน้ำดำเข้ากันมาก
# เนื้อหมู : เป็นคุโรบูตะ อร่อยนุ่มลิ้น
# เนื้อเป็ด : จะหนึบๆ ไม่เหนียว ไม่คาว แต่ทานได้จานเดียวรู้สึกว่าพอแล้ว
# ไก่ไม้ไผ่ : เป็นไก่บด ลืมถ่ายรูปมา รสชาติกรุบๆ แตาส่วนตัวเฉยๆ
#
# ช่วงโควิด บาร์ผักกับน้ำ จะมีพนักงานตักให้ เราอยากได้อะไรก็ไปจิ้มๆเลือกๆได้เลย
#
# ของหวาน มีไอติมกับไดฟูกุ ลองสั่งแต่ไดฟูกุ ไอติมไม่ไหวแย้ววว สั่งมาสามรส สตอเบอรี่ ชาเขียว ถั่วแดง อร่อยทั้งหมดค่ะ
#
# ::สรุป:: อร่อยคุ้มค่ากับราคา แต่คงไม่ได้มาทานบ่อยๆ ตกคนละ 600++ แต่ถ้าใครไม่ทานเนื้อวัว อาจจะไม่คุ้มเท่าไร
#
#  index 4
#  Review ถ้านึกถึงชาบูที่มีเนื้อเน้นๆ ในราคาไม่โหดจนเกินไป ก็นึกถึงโมโม่ตลอด บางทีทางร้านก็จะมีโปรมา 4 จ่าย 3 ในวันธรรมดาด้วยนะ
# ส่วนตัวชอบเนื้อออส เพราะมันไม่เยอะเกินไป (จริงๆมันเยอะก็อร่อยนะ แต่ทานมากๆแล้วเลี่ยนไว)
#
# อีกอย่างที่ชอบก็คือไอศกรีมรสชาเขียว และรสข้าว ไปทีไรสั่ง 2 ถ้วยตลอด
#
#  index 5
#  Review เดินมาหน้าร้านแล้วได้กลิ่นชาบูหอมมาก ๆ  ประกอบกับมีโปรบัตรเครดิตด้วย เลยตัดสินใจว่ากินร้านนี้ละกัน น้ำชาบูเลือกได้  2 อย่าง พวกเนื้อต่าง ๆ ต้องสั่งมา ส่วนผักเส้น และลูกชิ้น ไปตักเองได้เลย มีให้เลือกหลากหลายค่ะ
#
# สาขานี้ที่นั่งกว้างขวาง นั่งสบาย ไม่เหมือนกับสาขา  CTW  ที่จะค่อนข้างแคบ มีเด็กมาด้วยนั่งสบายดีค่ะ
#
# เนื้อต่าง ๆ คุณภาพดี บริการรวดเร็ว ขนมอร่อยค่ะ
#
#  index 6
#  Review ร้านบุฟเฟ่ ชาบูแนวญี่ปุ่น สายเนื้อหมู เนื้อวัวน่าจะคุ้มมากค่ะ
# ทางร้านมีโซนผักให้เลือกหยิบได้เอง
# เนื้อสามารถสั่งผ่านพนักงานได้เลยค่ะ
# ราคามีโปรโมชั่น เป็นบางช่วงนะคะ
# ใครชอบน้ำจิ้มพอนซึ ต้องลองค่ะ
# ของหวานเราชอบนะ ไอติมบ๋วยอร่อยดี
#
#  index 7
#  Review Number 20 : โมโม – พาราไดส์ (สาขาเดอะมอลบางกะปิ)
# ร้านอาหารบุฟเฟ่สุกี้ ชาบูน้ำดำ สไตล์ญี่ปุ่นที่แท้จริง  กรรมวิธีดังเดิม แต่รสชาติ ไทยประยุคก์
# วันนี้มาทาน Menu : บุฟเฟ่ต์สุกี้ชาบูน้ำดำ
# รายละเอียดเมนู : เลือกน้ำได้หลายแบบ แต่น้ำจิ้มมีแต่พอนซึ และน้ำจิ้มเฉพาะแบบฉบับของร้านโมโมฯ อาหารแบ่งเป็นชุดเซ็ทหมู หรือ เนื้อเลือกได้ ผักมีหลากหลายชนิด
# ราคา :  600+บาท / คน  คะแนน : 4.0/5
#
#  index 8
#  Review ร้านชาบูเฟรนไชส์รสชาติดีมากคุ้มค่าเหมาะสมกับราคาประมาณ500กว่าบาท ติดแต่เรื่องน้ำซุปตอนที่เริ่มงวด อาจจะเค็มขึ้นบ้างแต่ก็เป็นปกติของการกินชาบูอยู่แล้วครับ มีน้ำชาเขียวร้อนและกาแฟด้วย ซึ่งร้านทั่วไปไม่ค่อยมี แต่ที่ชอบเลยคือเนื้อออสเตรเลียดีมากๆครับ หมูสันคอก็รสชาติดีมากเลย แนะนำน้ำซุปสุกี้ยากี้ เสิร์ฟกับน้ำจิ้มไข่ไก่
# และโชยุหวาน ส่งนไอศครีมบ๊วยคือดีที่สุดครับ แนะนำต้องไปตำครับ ลุย!!!!
#
#  index 9
#  Review มา านที่ขาบูชิต้องมาตอนหิว ไม่งั้นจะไม่คุ้มนะครับ ฮ่าๆ เพราะเมนูของกินมันเยอะมาก ทั้งอาหารบนสายพาน อาหารทานเล่น ซูชิ ปูอัด เกี๊ยวซ่า กุ้งเทมปุระ มันละลานตามาก ราคาตอนนี้ 399 บาท แพงมั้ย..ก็นิดนึง แต่ถ้าเทียบกับอาหารแล้วก็ถือว่าคุ้มครับ
#
#  index 10
#  Review ใครชอบกุ้งทอดเทมปุระ แค่กุ้งเทมปุระก็คุ้มแล้ว ครั้งนี้มาทานดึกไปหน่อยมีของไม่ค่อยมากแล้ว นึกผิดหวังอยู่เพราะเหลือกุ้งเทมปุระอยู่ไม่กี่ตัว แต่ไม่นานก็ทอดใหม่มาเติมเลยได้ทานสมใจ กลายเป็นมาชาบูชิเพื่อทานอาหารญี่ปุนพวกซูชิ กุ้งเทมปุระเป็นหลัก ส่วนชาบูเป็นอาหารเสริมซะงั้น แต่ช่วงนี้จะไม่มีเมนูปลาไข่ชั่วคราวน้ะครับ และยังไงก็อย่าลืมทานไอติมให้เย็นชื่นใจตบท้ายด้วย
#
#  index 11
#  Review กลับมาอัพเดทราคาชาบูชิ ตอนนี้อยู่ที่ 399 บาท net ทานได้ประมาณ 1.15 ชม. น้ำซุปมีให้เลือก 4 รส ซูชิลายตามากๆ เทมปุระก็ทานเพลินๆดี ไปยืนตรงนั้นมีแต่ของน่าทานไปหมด ไลน์ของคาวบุฟเฟ่ต์เน้นกุ้งสด เบค่อน และเนื้อสไลด์ เป็นหลัก อิ่มคุ้มมาก
#
#  index 12
#  Review ห่างหายไปนานสำหรับชาบูชิ ตั้งแต่ทางร้านได้ปรับขึ้นราคา แถมลดเวลาลงด้วย คุณภาพอาหารดูแย่ลง ก็ลาขาด วันนี้กลับมาอีกครั้ง เนื่องจากได้ยินข่าวมาว่า "กุ้งปอกเปลือก" กลับมาแล้ว งานนี้เลยมาเพราะกุ้งค่ะ
#
# Shabushi ตั้งอยู่ชั้น G ของห้างเดอะมอลล์ บางกะปิ ตัวร้านตั้งอยู่โซนหน้าห้าง ฝั่งติดถนนใหญ่ หาไม่ยากค่ะ ร้านใหญ่ เด่นมาก สำหรับสาขานี้ถ้าเป็นวันเสาร์-อาทิตย์ หรือถ้าตรงกับวันหยุด คนจะเยอะมาก รอคิวนานมากๆ (นี่เป็นอีกหนึ่งสาเหตุที่เลิกกิน) แต่ถ้าเป็นวันธรรมดาคนไม่ค่อยเยอะเท่าไหร่ค่ะ ร้านกว้างขวาง จุคนได้เยอะ แต่ถ้าคนแน่นๆก็รู้สึกแออัดเหมือนกันค่ะ
#
# สำหรับอาหารของสาขานี้ ถ้าเทียบกับสาขาอื่นที่เคยกินแล้วรู้สึกว่า สด สะอาด ในระดับใช้ได้ค่ะ แต่ของบนสายพานออกไม่ครบนะคะ บางรายการต้องขอจากพนักงานค่ะ ถึงจะได้กิน แต่กุ้งสดออกมาตลอดค่ะ ไม่ขาด ถูกใจมาก เพราะวันนี้ตั้งใจมากินกุ้ง ราคาบุฟเฟ่ต์ 359 Net/คน กินได้ 1 ชั่วโมง 15 นาที โดยประมาณค่ะ
#
# อาหารที่ทานวันนี้
# - ซูชิ รสชาติธรรมดาค่ะ ปลาดิบสดใช้ได้
#
# - โอเด้ง ส่วนใหญ่เป็นลูกชิ้น รสชาติโอเคเลย
#
# - กุ้งเทมปุระ ทอดมาได้กรอบดี ไม่อมน้ำมัน แต่แป้งหนาไปนิด
#
# - เนื้อสไลด์ เนื้อส่วนนี้ติดมันมานิดๆ นุ่มดีค่ะ
#
# - เบคอน สไลด์มาบางมาก นุ่มและหอม อร่อย
#
# - กุ้งสด ปอกเปลือกมาอย่างดี จากที่เมื่อก่อนเหมือนกุ้งขาดสารอาหาร สดดี ตัวใหญ่ใช้ได้ กินคนเดียว 5 จานได้ค่ะ
#
# - หอยตลับ ตัวไม่ใหญ่มาก แต่สด เนื้อหวานเด้งดี
#
# - ตับหมู สดและนุ่มดี
#
# - น้ำฝรั่ง เปรี้ยวหวาน ชื่นใจดี แต่วางทิ้งไว้นานๆแล้วจืดค่ะ
#
# - โฟลตไอศกรีมวานิลา เมนูของหวานที่ทำเองโดยการกดสไปรท์ครึ่งแก้ว แล้วตักไอติมวานิลา 1 ลูกใส่ลงไปก็กินได้แล้วค่ะ หวานหอม ชื่นใจดีค่ะ
#
#
# โดยรวมแล้วสำหรับมื้อนี้ถือว่าคุ้มค่ะ ไม่ผิดหวังที่กลับมาอีกครั้ง แต่ขอติงเรื่องเวลา 1 ชั่วโมง 15 นาที ส่วนตัวแล้วคิดว่าน้อยไปหน่อยค่ะ ใครที่ไปกินก็ดูเวลานิดนึง อย่ากินเพลิน เหลือเวลาไว้ตอนเช็คบิลด้วยก็ดี ค่ะ เพราะถ้าคนรอเช็คบิลเยอะแล้วยังไม่ถึงคิวเรา ถ้าเกินเวลาจะโดนปรับเอาได้นะคะ (เพื่อนโดนมาแล้วค่ะ)
#
#  index 13
#  Review เมื่อหลายวันก่อนนัดหาข้าวทานกับเดอะแกงค์ และก็ลงเอยด้วยอาหารบุฟเฟ่ต์ร้านนี้ค่ะ
#
# ร้านนี้ตั้งอยุ่ชั้น G ใหญ่พอสมควร
#
# ราคาต่อคน : 359 บาท เวลา1:15 ชม.
#
# รสชาติ: อาหารสด ใหม่
# หมุสไลด์ รสชาติดี นุ่ม อร่อย
# ซูชิ พอทานได้ค่ะ ออกตลอด
# ไอศกรีม: หลากรส วนิลา สตอเบอร์รี่ ชอคโกแลต มะนาว ฯ
# และอื่นๆอีกมากมาย
#
#  index 14
#  Review บอกตรงๆว่าหลายครั้งที่เลือกจะกินบุฟเฟต์จะต้องอารามณ์เสียกับการรอคิวนานๆจนสุดท้ายเลิกรอไม่กินมันซะเลย ยิ่ง Shabushi นะคนเยอะตลอด แต่วันนี้โชคดีคนน้อยน่าจะรอได้ขอจัดซะหน่อยพลาดมาหลายรอบหล่ะ เลยไปจองคิว วันนี้มากินที่สาขาเดอะมอลล์ บางกะปิ ร้านอยู่ชั้น G ใกล้ๆกับประตูปทางเข้าหน้าห้างเลย พอได้ที่นั่งแล้วก็หยิบๆทุกอย่างที่อยากกินแบบชั่วโมงครึ่งนับจากนี้พี่ขอจัดเต็ม โดยร่วมๆเราว่าพวกเนื้อ ผัก ชูชิ ก็ดูโอเคนะผักดูสดกว่าหลายๆร้านที่เป็นบุฟเฟต์สายพานร้านอื่นๆ พนักงานขยันเดินดี ราคาสามร้อยกว่าบาทต่อคนก็ไม่แพงนะ
#
#  index 15
#  Review สวัสดีครับวันนี้จะขอมารีวิวร้านชาบูชิ บุฟเฟขวัญใจของใครๆ หลายคนเมนูทางร้านมีให้เลือกมากมาย ผ่านระบบสายพานที่ให้ลูกค้าสามารถหยิบได้อย่างทั่วถึง มีทั้งข้อดีและเสีย 555 การบริการก็ดีครับ เก้บจานที่ใช้แล้วอยู่เรื่อย นํ้าซุปก็สามารถเลือกได้ตามแบบที่ต้องการ นํ้าจิ้มก็อร่อยครับ ใครมี่ไม่เคยทานต้องลองทานดูนะครับอร่อยคุ้ม
#
#  index 16
#  Review ชาบูชิ สาขาเดอะมอลล์บางกะปิ ตั้งอยู่ประตูหน้าห้าง ตรงข้ามแมคโดนัลเลยค่ะ ขนาดร้านใหญ่โตดี แต่ไปทีไรต้องต่อคิวตลอด สั้นบ้างยาวบ้างแล้วแต่โชคชะตา แต่ห้างมักจะจัดซุ้มออกร้านโน้นนี่ตรงบริเวณลานหน้าร้านให้เลือกชอปเบาๆระหว่างรอ (เป็นกลยุทธ์ที่ดีมากๆ555)
#
# ในร้านก็จะมีทั้งเคาน์เตอร์ยาวหน้าสายพานยาวเป็นแนว แบบหม้อใครหม้อท่าน และโต๊ะแบบหมู่คณะหม้อรวมด้วย
#
# อาหารบนสายพานก็เคลื่อนตัวมาให้เลือกมากมาย คอเนื้อก็แน่นจานดำหยิบวางต้มกันเลยค่า น้ำซุปมีให้เลือก3แบบ ใส ข้น ต้มยำ(ถ้าจำไม่ผิด อิอิ)
#
# คุณภาพอาหารล่าสุดที่ไปทาน ปรับปรุงดีขึ้นมาก ของทานเล่นเช่น ชูชิ ข้าวปั้น ของทอด สลัด ของหวาน ไอติมมีเมนูใหม่ๆเยอะมากขึ้นและเติมตลอด ยอดไปเลย
#
# คุ้มค่าในราคา3xx บาท  แถมมีบัตรสมาชิกเครือโออิชิลดอีก มันดีตรงนี้ละค่า^^
#
#  index 17
#  Review หลังจากที่เคยลองสาขายูเนี่ยนมอลล์ไป รอบนี้มาที่สาขาเดอะมอลล์บางกะปิชั้น 4 โซน MCC HALL ด้านในสุดติดกับพวกค่ายมวย ตอนแรกก็นึกว่าชาบู 199 ธรรมดา แต่ที่ไหนได้ มีพิซซ่าจากนารายพิซเซอเรียด้วย
#
# สำหรับราคา 199 บาท จะทานพวกหมูได้ทั้งหมด รวมถึงพิซซ่า ของทอด ซุปต่างๆ แกงเขียวหวาน ได้น้ำซุป 1 รสชาติ
#
# - ถ้าอยากได้น้ำซุปเพิ่มเป็น 2 รสชาติ จ่ายเพิ่มคนละ 40 บาท
# - น้ำดื่มรีฟีล 39 บาท
# - ส่วนใครอยากทานเนื้อก็เพิ่มคนละ 49 บาท
# - ซูชิและของหวานสั่งเพิ่มโดยจ่ายราคาตามเมนู
#
# รวมๆก็ถือว่าอิ่มคุ้มดีนะ ถึงเบค่อนจะมันเยอะไปหน่อย น้ำซุปจะไม่ได้เข้มข้นมากนัก แต่ในราคานี้ มีตัวเลือกให้เท่านี้ วันไหนหิวมากๆก็จะแวะไปใหม่แน่นอน
#
#  index 18
#  Review ร้านบุฟเฟ่ต์ที่มีโปรโมชั่นหัวละ199บาท ไม่รวมน้ำ ไม่รวมVAT ไปทานวันธรรมดา ชอบมากเพราะได้เวลาทานตั้ง2ชม. เต็มๆ มีค่าน้ำซุป คนละ10บาท มีน้ำซุปเลือกได้6แบบ แต่หม้อแบ่งได้3ช่อง น้ำซึปต้มยำอร่อยดีครับ แนะนำให้เลือกอันนี้อันนึง ในชุดบุฟเฟ่ต์ ไม่มีซีฟู้ดน่ะครับ แต่อาหารก็มีให้เลือกเยอะน่ะครับ ที่สำคัญมีพิซซ่าอยู่ในชุดบุฟเฟ่ต์ด้วย ของนารายพิซเซอเรีย รับประกันความอร่อย นอกจากนี้ทุกสัปดาห์หลังวันหวยออก เอาลอตเตอรี่ที่ถูกหวยกิน มาแลกฮันนี่โทสฟรีน่ะครับ แนะนำให้มาทานเลยจ้า บุฟเฟ่ต์ร้านนี้ กำเงินมาคนละ300 มีทอนแน่นอนครับ
#
#  index 19
#  Review เคยรู้จักร้านนี้จากที่ union mall ไม่เคยได้ลองกิน แต่จำได้ขึ้นใจจากชื่อร้าน 😆
#
# จากชื่อก็บอกอยู่แล้วว่าเป็นร้าน "ชาบู" แต่เนื่องจากเป็นของ Narai pizzeria ในไลน์อาหารจึงมี pizza ด้วยซะเลย ยังมี สปาเกตตี้ ไก่นิวออลีน
#
# อาหารปรุงสุกก็มีอย่างอื่นอีกนิดหน่อย ที่รู้สึกว่าอร่อยเลยคือ ข้าวมันไก่ 🤣 ตัดกำลังจริงๆ
#
# พวกของสดก็หลากหลาย บางส่วนอยู่ในตู้ให้หยิบ บางส่วนก็ใช้เขียนสั่งเอา คุณภาพก็เหมาะสมตามราคา
#
# บริการค่อนข้างดี พนักงานขยัน
#
#  index 20
#  Review อร่อยมากค่ะ คุ้มค่าสมราคา บุฟเฟ่หมูผักต่างๆ รวมน้ำด้วยจบที่ 255 /ท่าน เด็ดๆคือมีพิซซ่าบุพเฟ่ ดีเริสมากๆ รสชาตไม่กาไก่เรยนะ คืองานดีเเป้งนุ่มหอมมากๆ  ตบท้ายด้วยของหวานอร่อย โชคดีมากๆไปช่วงโปรโมชั่นของหวานราคา 29 จาก 128 คือ เซตไอติม+บราวนี่+วิปครีม อร่อยยมากกก บุฟเฟ่จุกๆปิดท้ายของหวานเเบบสวยๆ
#
#  index 21
#  Review ก็ตามที่เขียนเลยครับ ว่า ถ้าจะจ่ายในราคา 199 บาท คุณต้องจ่ายด้วยเงินสดนะครับ และราคานี้ ยังไม่รวมน้ำ และ VAT 7% รวมถึงอย่างอื่นๆ ที่คุณสั่งเพิ่มได้ เช่น เนื้อวัว,ซูชิ,ของหวาน เป็นต้น
# แม้จะดูแปลกหน่อย แต่ก็ถือว่าโอเคมาก แม้ซูชิต้องสั่งเพิ่ม แต่ก็มีอาหารอื่นๆ ทดแทน โดยเฉพาะพิซซ่า ที่ได้ลองทั้ง 3 หน้า อร่อยมาก และถ้ากินตอนนำของมาลงสดๆ ร้อนๆ จะอร่อยกว่าปรกติครับ

# %%
for index, row in df.iterrows():
    print(" index {} \n Review {} \n".format(index+1,row['Review_tokenized']))
# Out:
#  index 1
#  Review บริการ,ดีมาก,พนักงาน,น่ารัก,สะอาดสะอ้าน,ใส่ใจ,ประทับใจ,การบริการรสชาติ,อาหารอันนี้,แปลกใหม่,เซ็ท,บาท,อาหาร,จำกัด,หลากหลาย,แต่เพียงพอกับ,ความต้องการ,กิน,เนื้อ,กิน,สัน,คอ,ถาด,เป็ด,แฟน,กิน,เนื้อ,คุณภาพดี,น้ำ,ซุป,ดำ,เผ็ด,น้ำจิ้ม,อร่อย,เคยกิน,รสชาติ,แบบนี้,มาก่อน,เต้าเจี้ยว,เคลม,รสชาติดีนะ,ถามราคา,โดยรวม,คุ้ม,โมจิ,อร่อย,ไอติมก็,อร่อย,ไม่ต้องออก,กิน,ข้างนอก,สรุป,ประทับใจ,บริการ,คุณภาพ,ของอาหาร
#
#  index 2
#  Review นึกถึง,ชาบู,ญี่ปุ่น,คิดถึง,โม,โม่,พาราไดซ์,คุณภาพ,เค้า,มาตรา,ฐาน,มีโอกาสมาทานก่อนร้าน,นาที,ร้านก็,บริการ,ดี,อาหาร,เครื่องดื่ม,ที่ทาง,ทะยอย,แจ้ง,รายละเอียด,การงดรับ,ออร์เดอร์,สาขานี้,พนักงานบริการดี,น่ารัก,เป็นกันเอง,เหวี่ยง,เจอ,สาขา,พระราม,โอเค,พนักงาน,ทำงานมาก,CTW,พรีเมียม,การบริการก็,สู้,สาขานี้,Terminal,ลูกค้า
#
#  index 3
#  Review ทาน,นั่ง,โต๊ะ,หม้อ,เดียวกันได้,โต๊ะ,ยังมี,ฉาก,กั้น,น้ำ,ซุป,เลือก,รส,น้ำจิ้ม,แตกต่างกัน,ตามน้ำ,ซุป,เลือก,ชาบู,น้ำ,ดำ,น้ำ,ซุป,เห็ด,ชาบู,น้ำ,ดำ,หวาน,เค็ม,รสชาติ,เข้มข้น,เสิร์ฟ,ไข่,สด,เป็นผู้ใหญ่,ชอบ,หวาน,ชอบ,น้ำ,ซุป,เห็ด,มีชื่อ,ภาษา,ญี่ปุ่น,เสิร์ฟ,มากับ,เห็ด,น้ำจิ้ม,ซอย,ซอส,รสชาติ,จืด,แนว,น้ำ,ซุป,ใส,เนื้อสัตว์,เลือก,เนื้อวัว,เนื้อหมู,เนื้อ,เป็ด,ไก่,ไม้,ไผ่,สั่ง,ลอง,เนื้อวัว,อร่อย,มากก,ชิ้น,เนื้อ,นุ่ม,กิน,ชาบู,น้ำ,ดำ,เข้ากัน,เนื้อหมู,คุ,โร,บูต,ะ,อร่อย,นุ่ม,ลิ้น,เนื้อ,เป็ด,หนึบ,เหนียว,คาว,ทาน,จาน,รู้สึก,ไก่,ไม้,ไผ่,ไก่,บด,ลืม,ถ่ายรูปมา,รสชาติกรุบ,แ,ตา,ส่วนตัว,โควิด,บาร์,ผัก,น้ำ,พนักงาน,ตัก,อยากได้,จิ้ม,เลือก,ของหวาน,ไอติมกับ,ไดฟูกุ,ลอง,สั่ง,ไดฟูกุ,ไอติม,ไหว,แย้,ววว,สั่ง,มาสามรส,สตอ,เ,บอ,รี่,ชาเขียว,ถั่ว,แดง,อร่อย,สรุป,อร่อย,คุ้มค่า,ราคา,ทานบ่อยๆ,ตก,คนละ,ทาน,เนื้อวัว,คุ้ม
#
#  index 4
#  Review นึกถึง,ชาบูที่,เนื้อ,ราคา,โหด,เกินไป,นึกถึง,โม,โม่,ร้านก็,โปรมา,จ่าย,ธรรมดาด้วย,ส่วนตัว,ชอบ,เนื้อ,ออ,ส,เกินไป,อร่อย,ทานมาก,เลี่ยน,ไว,อีกอย่าง,ชอบ,ไอศกรีมรส,ชาเขียว,รส,ข้าว,สั่ง,ถ้วย
#
#  index 5
#  Review เดิน,หน้า,ได้กลิ่น,ชาบู,หอมมาก,ประกอบกับ,โปรบัตรเครดิต,ตัดสินใจ,กิน,น้ำชาบู,เลือก,เนื้อ,ต่าง ๆ,สั่ง,ผัก,เส้น,ลูกชิ้น,ตัก,เลือก,หลากหลาย,สาขานี้,ที่นั่ง,นั่ง,เหมือนกับ,สาขา,CTW,ที่จะ,แคบ,เด็ก,มาด้วย,นั่ง,สบายดี,เนื้อ,ต่าง ๆ,คุณภาพดี,บริการ,ขนมอร่อย
#
#  index 6
#  Review ร้านบุ,ฟเฟ่,ชาบู,แนว,ญี่ปุ่น,สาย,เนื้อหมู,เนื้อวัว,คุ้ม,มากค่ะ,ร้านมี,โซน,ผัก,เลือก,หยิบ,เนื้อ,สั่ง,ผ่านพนักงาน,ราคามี,โปรโมชั่น,นะคะ,ชอบ,น้ำจิ้ม,พอน,ซึ,ลอง,ของหวาน,ชอบ,ไอติม,บ๋ว,ยอ,ร่อย,ดี
#
#  index 7
#  Review Number,โม,โม,–,พารา,ได,ส์,สาขา,เดอะ,มอ,ลบ,า,งก,ะปิ),ร้านอาหารบุ,ฟเฟ่,สุกี้,ชาบู,น้ำ,ดำ,สไตล์,ญี่ปุ่น,กรรมวิธี,ดังเดิม,รสชาติ,ไทย,ประ,ยุค,ก์,ทาน,Menu,บุฟเฟ่ต์,สุกี้,ชาบู,น้ำ,ดำ,รายละเอียด,เมนู,เลือก,น้ำ,น้ำจิ้ม,พอน,ซึ,น้ำจิ้ม,แบบฉบับ,โม,โม,อาหาร,แบ่ง,ชุด,เซ็ท,หมู,เนื้อ,เลือก,ผัก,หลากหลายชนิด,ราคา,บาท,คน,คะแนน
#
#  index 8
#  Review ชาบู,เฟรนไชส์,รสชาติดีมากคุ้มค่า,เหมาะสม,ราคา,บาท,ติด,เรื่อง,น้ำ,ซุป,ตอนที่,งวด,เค็ม,เป็นปกติ,ของการกิน,ชาบู,อยู่แล้ว,มีน้ำชาเขียว,ร้อน,กาแฟ,ร้านทั่วไป,ไม่ค่อยมี,ชอบ,เนื้อ,ออสเตรเลีย,ดีมาก,หมู,สัน,คอก็,รสชาติดีมาก,แนะนำ,น้ำ,ซุป,สุกี้ยากี้,เสิร์ฟ,น้ำจิ้ม,ไข่ไก่,โชย,ุ,หวาน,น,ไอศครีม,บ๊วย,ดี,แนะนำ,ตำ,ลุย
#
#  index 9
#  Review มานที่,ขาบูชิต,้,อง,ตอน,หิว,ไม่งั้น,คุ้ม,ฮ่า,เมนู,ของกิน,อาหารบน,สายพาน,อาหารทาน,เล่น,ซูชิ,ปูอัด,เกี๊ยว,ซ่า,กุ้ง,เท,ม,ปุระ,ละลานตามาก,ราคา,ตอนนี้,บาท,แพงมั้ย,นิดนึง,เทียบ,อาหาร,แล้วก็,คุ้ม
#
#  index 10
#  Review ชอบ,กุ้ง,ทอด,เท,ม,ปุระ,กุ้ง,เท,ม,ปุระ,คุ้ม,ทาน,ดึก,หน่อยมี,ไม่ค่อยมาก,นึก,ผิดหวัง,เหลือกุ้ง,เท,ม,ปุระ,กี่,ตัว,นานก็,ทอด,เติม,ทาน,สมใจ,กลายเป็นมา,ชาบู,ชิ,ทานอาหาร,ญี่,ปุ,นพ,วก,ซูชิ,กุ้ง,เท,ม,ปุระ,เป็นหลัก,ชาบู,อาหารเสริม,ซะงั้น,เมนู,ปลา,ไข่,ชั่วคราวน,้ะ,อย่า,ลืม,ทาน,ไอติม,เย็นชื่นใจ,ตบท้าย
#
#  index 11
#  Review กลับมา,อัพเดท,ราคา,ชาบู,ชิ,ตอนนี้,บาท,net,ทาน,ชม.,น้ำ,ซุป,เลือก,รส,ซูชิลายตามาก,เท,ม,ปุระ,ทาน,เพลิน,ดี,ไปยืน,ตรงนั้น,ทาน,ไลน์,ของคาว,บุฟเฟ่ต์,กุ้ง,สด,เบ,เนื้อ,สไลด์,เป็นหลัก,อิ่ม,คุ้ม
#
#  index 12
#  Review ห่างหาย,สำหรับ,ชาบู,ชิ,ขึ้นราคา,แถมลด,เวลา,คุณภาพอาหารดู,แย่,ลาขาด,กลับมา,อีกครั้ง,ได้ยิน,ข่าว,กุ้ง,ปอกเปลือก,กลับมา,งาน,กุ้ง,Shabushi,ตั้งอยู่,ชั้น,G,ห้าง,เดอะ,มอลล์,บางกะปิ,ตัว,ตั้งอยู่,โซน,หน้า,ห้าง,ฝั่ง,ติด,ถนนใหญ่,หาไม่,ยากค่ะ,เด่นมาก,สำหรับ,สาขานี้,เสาร์,อาทิตย์,วันหยุด,คน,รอ,คิว,นานมาก,อีกหนึ่ง,สาเหตุ,เลิก,กิน,ธรรมดา,คน,ร้านกว้างขวาง,จุ,คน,คน,แน่น,รู้สึก,แออัด,เหมือนกัน,สำหรับ,อาหาร,สาขานี้,เทียบ,สาขา,เคยกิน,แล้วรู้สึก,สด,สะอาด,ระดับ,ใช้ได้,ของบน,สายพานออก,นะคะ,บางรายการ,พนักงานค่ะ,กิน,กุ้ง,สด,ออกมา,ถูกใจมาก,ตั้งใจมากิน,กุ้ง,ราคาบุฟเฟ่ต์,Net,คน,กิน,ชั่วโมง,นาที,โดยประมาณ,อาหารที่,ทานวันนี้,ซูชิ,รสชาติธรรมดา,ปลาดิบ,สด,ใช้ได้,โอ,เด้ง,ลูกชิ้น,รสชาติ,โอเค,กุ้ง,เท,ม,ปุระ,ทอดมา,กรอบดี,อม,น้ำมัน,แป้ง,หนา,เนื้อ,สไลด์,เนื้อ,ติดมัน,มานิดๆ,นุ่ม,ดี,เบคอน,สไลด์,มาบางมาก,นุ่ม,หอม,อร่อย,กุ้ง,สด,ปอกเปลือก,เหมือนกุ้ง,ขาดสารอาหาร,สด,ดี,ตัว,ใช้ได้,กิน,คนเดียว,จาน,หอย,ตลับ,ตัว,สด,เนื้อ,หวาน,เด้งดี,ตับ,หมู,สด,นุ่ม,ดี,น้ำ,ฝรั่ง,เปรี้ยวหวาน,ชื่นใจดี,วาง,ทิ้ง,จืด,โฟลต,ไอศกรีม,วานิลา,เมนู,ของหวานที่,ทำ,โดยการกด,สไปรท์,ครึ่ง,แก้ว,แล้วตัก,ไอติม,วานิลา,ลูก,ใส่,กิน,หวาน,หอม,ชื่นใจดี,โดยรวม,สำหรับ,มื้อ,คุ้ม,ผิดหวัง,กลับมา,อีกครั้ง,ติง,เรื่อง,เวลา,ชั่วโมง,นาที,ส่วนตัว,ว่าน้อย,กิน,ดู,เวลา,นิดนึง,อย่า,กิน,เพลิน,เวลา,ตอน,เช็คบิลด้วย,คน,รอ,เช็คบิล,คิว,เวลา,โดน,นะคะ,เพื่อน,โดนมา
#
#  index 13
#  Review วันก่อน,นัด,หา,ข้าวทานกับ,เดอะ,แกงค์,ลงเอย,อาหารบุฟเฟ่ต์,อย,ุ่,ชั้น,G,ราคา,คน,บาท,เวลา,ชม.,รสชาติ,อาหารสด,ห,มุ,สไลด์,รสชาติดี,นุ่ม,อร่อย,ซูชิ,ทาน,ไอศกรีม,หลากรส,วน,ิ,ลา,สตอ,เบอร์รี่,ชอค,โก,แล,ต,มะนาว,อีกมากมาย
#
#  index 14
#  Review หลายครั้ง,เลือก,กิน,บุฟเฟต์,ต้องอาราม,ณ์,การรอ,คิว,สุดท้าย,เลิก,รอ,กิน,Shabushi,คน,แต่วันนี้,โชคดี,คน,รอ,พลาด,รอบ,หล่ะ,จอง,คิว,มากินที่,สาขา,เดอะ,มอลล์,บางกะปิ,ร้านอยู่,ชั้น,G,ประตู,ป,ทางเข้าหน้า,ห้าง,พอได้ที่นั่ง,แล้วก็,หยิบ,กิน,ชั่วโมง,ครึ่ง,พี่,เต็ม,เนื้อ,ผัก,ชู,ชิ,ดูโอเคนะ,ผัก,ดู,สดกว่า,ร้านที่,บุฟเฟต์,สายพานร้านอื่นๆ,พนักงานขยัน,เดิน,ดี,ราคาสามร้อย,บาท,คน,แพง
#
#  index 15
#  Review สวัสดี,ขอมารีวิวร้าน,ชาบู,ชิ,บุ,ฟเฟ,ขวัญใจ,คน,เมนู,ร้านมี,เลือก,ผ่านระบบ,สายพานที่,ลูกค้า,หยิบ,ทั่วถึง,ข้อดี,การบริการก็ดี,เก้,บ,จานที่,ใช้แล้วอยู่,น้ำ,ซุป,เลือก,แบบที่,ต้องการ,น้ำจิ้ม,อร่อย,มี่,ทาน,ลอง,ทาน,ดู,อร่อย,คุ้ม
#
#  index 16
#  Review ชาบู,ชิ,สาขา,เดอะ,มอลล์,บางกะปิ,ตั้งอยู่,ประตู,หน้า,ห้าง,ตรงข้าม,แมค,โดน,ัล,ขนาด,ดี,คิว,โชคชะตา,ห้างมักจะ,ซุ้ม,ออกร้าน,โน้น,บริเวณ,ลาน,หน้า,เลือก,ช,อป,เบา,รอ,กลยุทธ์,ดีมาก,ๆ),ร้านก็,เคาน์เตอร์,หน้า,สายพานยาว,เป็นแนว,หม้อ,หม้อ,ท่าน,โต๊ะ,หมู่คณะ,หม้อ,อาหารบน,สายพานก็,เคลื่อนตัว,เลือก,คอ,เนื้อ,แน่น,จาน,ดำ,หยิบ,วาง,ต้ม,ค่า,น้ำ,ซุป,เลือก,ใส,ข้น,ต้มยำ,อิอิ,คุณภาพอาหาร,ทาน,ปรับปรุงดีขึ้น,ทาน,เล่น,ชู,ชิ,ข้าวปั้น,ทอด,สลัด,ของหวาน,ไอติม,เมนู,มากขึ้น,เติม,ยอด,คุ้มค่า,ราคา,บาท,แถม,บัตรสมาชิก,เครือ,โออิชิ,ลด,มันดี,ตรงนี้,ค่า
#
#  index 17
#  Review หลังจากที่,เคยลอง,สาขายู,นม,อลล์,รอบนี้,สาขา,เดอะ,มอลล์,บางกะปิ,ชั้น,โซน,MCC,HALL,ด้านใน,ติดกับ,ค่ายมวย,ตอนแรกก็,นึก,ชาบู,ธรรมดา,ที่ไหนได้,พิซซ่า,จากนาราย,พิซ,เซ,อ,เรียด,้วย,สำหรับ,ราคา,บาท,ทานพวก,หมู,พิซซ่า,ทอด,ซุป,แกงเขียวหวาน,น้ำ,ซุป,รสชาติ,อยากได้,น้ำ,ซุป,รสชาติ,จ่าย,คนละ,บาท,น้ำดื่ม,รีฟี,ล,บาท,ทาน,เนื้อ,คนละ,บาท,ซูชิ,ของหวาน,สั่ง,จ่าย,ราคาตาม,เมนู,อิ่ม,คุ้ม,ดีนะ,เบ,น้ำ,ซุป,เข้มข้น,มากนัก,ราคานี้,มีตัวเลือก,หิว,แวะ,แน่นอน
#
#  index 18
#  Review ร้านบุฟเฟ่ต์,โปรโมชั่น,หัว,บาท,น้ำ,VAT,ทานวัน,ธรรมดา,ชอบ,ได้เวลา,ทาน,ชม.,มีค่าน้ำ,ซุป,คนละ,บาท,มีน้ำ,ซุป,เลือก,หม้อ,แบ่ง,ได้ช่อง,น้ำ,ซึป,ต้มยำ,อร่อย,ดี,แนะนำ,เลือก,อันนี้,นึง,ชุด,บุฟเฟ่ต์,ซี,ฟู้ด,อาหารก็,เลือก,พิซซ่า,ชุด,บุฟเฟ่ต์,นาราย,พิซ,เซ,อ,เร,ีย,รับประกัน,อร่อย,สัปดาห์,หวย,ลอตเตอรี่,ถูกหวย,กิน,แลก,ฮัน,โทส,ฟรี,แนะนำ,ทาน,บุฟเฟ่ต์,กำ,เงิน,คนละ,ทอน,แน่นอนครับ
#
#  index 19
#  Review รู้จักร้าน,union,mall,ลอง,กิน,จำได้,ขึ้นใจ,จากชื่อ,จากชื่อ,บอกอยู่แล้ว,ชาบู,Narai,pizzeria,ไลน์,อาหาร,pizza,ยังมี,สปาเกตตี,้,ไก่,นิวออ,ลี,น,อาหาร,ปรุง,สุกก็,อย่างอื่น,อีกนิดหน่อย,รู้สึก,อร่อย,ข้าวมันไก่,ตัดกำลัง,ของสดก็,หลากหลาย,บางส่วน,ตู้,หยิบ,บางส่วน,สั่ง,คุณภาพก็,เหมาะสม,ตามราคา,บริการ,ค่อนข้างดี,พนักงานขยัน
#
#  index 20
#  Review อร่อย,มากค่ะ,คุ้มค่า,สมราคา,บุ,ฟเฟ่,หมู,ผัก,น้ำ,จบ,ท่าน,เด็ด,พิซซ่า,บุพ,เฟ่,ดี,เร,ิ,สมา,กๆ,รส,ชาต,กา,ไก่,เรย,งาน,ดี,แป้ง,นุ่ม,หอมมาก,ตบท้าย,ของหวานอร่อย,โชคดีมาก,โปรโมชั่น,ของหวานราคา,เซต,ไอติม,บรา,วน,ี่+,วิป,ครีม,อร่อย,ยม,า,กก,ก,บุ,ฟเฟ่,จุก,ปิดท้าย,ของหวาน,สวย
#
#  index 21
#  Review ก็ตามที่,จ่าย,ราคา,บาท,จ่าย,เงินสดนะ,ราคานี้,น้ำ,VAT,อย่างอื่นๆ,สั่ง,เนื้อวัว,ซูชิ,ของหวาน,ดู,แปลกหน่อย,โอเค,ซูชิต้อง,สั่ง,อาหารอื่นๆ,ทดแทน,โดยเฉพาะ,พิซซ่า,ลอง,หน้า,อร่อย,กิน,ตอน,ของมา,สดๆ ร้อนๆ,อร่อย,ปรกติ

# %%
from sklearn.feature_extraction.text import CountVectorizer

cvec = CountVectorizer(analyzer=lambda x:x.split(','))
c_feat = cvec.fit_transform(df['Review_tokenized'])

# %%
cvec.vocabulary_
# Out:
# {'CTW': 0,
#  'G': 1,
#  'HALL': 2,
#  'MCC': 3,
#  'Menu': 4,
#  'Narai': 5,
#  'Net': 6,
#  'Number': 7,
#  'Shabushi': 8,
#  'Terminal': 9,
#  'VAT': 10,
#  'mall': 11,
#  'net': 12,
#  'pizza': 13,
#  'pizzeria': 14,
#  'union': 15,
#  'ก': 16,
#  'กก': 17,
#  'กรรมวิธี': 18,
#  'กรอบดี': 19,
#  'กลยุทธ์': 20,
#  'กลับมา': 21,
#  'กลายเป็นมา': 22,
#  'กั้น': 23,
#  'กา': 24,
#  'การงดรับ': 25,
#  'การบริการก็': 26,
#  'การบริการก็ดี': 27,
#  'การบริการรสชาติ': 28,
#  'การรอ': 29,
#  'กาแฟ': 30,
#  'กำ': 31,
#  'กิน': 32,
#  'กี่': 33,
#  'กุ้ง': 34,
#  'กๆ': 35,
#  'ก็ตามที่': 36,
#  'ก์': 37,
#  'ขนมอร่อย': 38,
#  'ขนาด': 39,
#  'ขวัญใจ': 40,
#  'ของการกิน': 41,
#  'ของกิน': 42,
#  'ของคาว': 43,
#  'ของบน': 44,
#  'ของมา': 45,
#  'ของสดก็': 46,
#  'ของหวาน': 47,
#  'ของหวานที่': 48,
#  'ของหวานราคา': 49,
#  'ของหวานอร่อย': 50,
#  'ของอาหาร': 51,
#  'ขอมารีวิวร้าน': 52,
#  'ขาดสารอาหาร': 53,
#  'ขาบูชิต': 54,
#  'ขึ้นราคา': 55,
#  'ขึ้นใจ': 56,
#  'ข่าว': 57,
#  'ข้น': 58,
#  'ข้อดี': 59,
#  'ข้างนอก': 60,
#  'ข้าว': 61,
#  'ข้าวทานกับ': 62,
#  'ข้าวปั้น': 63,
#  'ข้าวมันไก่': 64,
#  'คน': 65,
#  'คนละ': 66,
#  'คนเดียว': 67,
#  'ครีม': 68,
#  'ครึ่ง': 69,
#  'ความต้องการ': 70,
#  'คอ': 71,
#  'คอก็': 72,
#  'คะแนน': 73,
#  'คาว': 74,
#  'คิดถึง': 75,
#  'คิว': 76,
#  'คุ': 77,
#  'คุณภาพ': 78,
#  'คุณภาพก็': 79,
#  'คุณภาพดี': 80,
#  'คุณภาพอาหาร': 81,
#  'คุณภาพอาหารดู': 82,
#  'คุ้ม': 83,
#  'คุ้มค่า': 84,
#  'ค่อนข้างดี': 85,
#  'ค่า': 86,
#  'ค่ายมวย': 87,
#  'งก': 88,
#  'งวด': 89,
#  'งาน': 90,
#  'จบ': 91,
#  'จอง': 92,
#  'จากชื่อ': 93,
#  'จากนาราย': 94,
#  'จาน': 95,
#  'จานที่': 96,
#  'จำกัด': 97,
#  'จำได้': 98,
#  'จิ้ม': 99,
#  'จืด': 100,
#  'จุ': 101,
#  'จุก': 102,
#  'จ่าย': 103,
#  'ฉาก': 104,
#  'ช': 105,
#  'ชม.': 106,
#  'ชอค': 107,
#  'ชอบ': 108,
#  'ชั่วคราวน': 109,
#  'ชั่วโมง': 110,
#  'ชั้น': 111,
#  'ชาต': 112,
#  'ชาบู': 113,
#  'ชาบูที่': 114,
#  'ชาเขียว': 115,
#  'ชิ': 116,
#  'ชิ้น': 117,
#  'ชื่นใจดี': 118,
#  'ชุด': 119,
#  'ชู': 120,
#  'ซอย': 121,
#  'ซอส': 122,
#  'ซะงั้น': 123,
#  'ซี': 124,
#  'ซึ': 125,
#  'ซึป': 126,
#  'ซุป': 127,
#  'ซุ้ม': 128,
#  'ซูชิ': 129,
#  'ซูชิต้อง': 130,
#  'ซูชิลายตามาก': 131,
#  'ซ่า': 132,
#  'ญี่': 133,
#  'ญี่ปุ่น': 134,
#  'ฐาน': 135,
#  'ณ์': 136,
#  'ดังเดิม': 137,
#  'ดำ': 138,
#  'ดี': 139,
#  'ดีนะ': 140,
#  'ดีมาก': 141,
#  'ดึก': 142,
#  'ดู': 143,
#  'ดูโอเคนะ': 144,
#  'ด้านใน': 145,
#  'ต': 146,
#  'ตก': 147,
#  'ตบท้าย': 148,
#  'ตรงข้าม': 149,
#  'ตรงนั้น': 150,
#  'ตรงนี้': 151,
#  'ตลับ': 152,
#  'ตอน': 153,
#  'ตอนที่': 154,
#  'ตอนนี้': 155,
#  'ตอนแรกก็': 156,
#  'ตัก': 157,
#  'ตัดกำลัง': 158,
#  'ตัดสินใจ': 159,
#  'ตับ': 160,
#  'ตัว': 161,
#  'ตั้งอยู่': 162,
#  'ตั้งใจมากิน': 163,
#  'ตา': 164,
#  'ตามน้ำ': 165,
#  'ตามราคา': 166,
#  'ตำ': 167,
#  'ติง': 168,
#  'ติด': 169,
#  'ติดกับ': 170,
#  'ติดมัน': 171,
#  'ตู้': 172,
#  'ต่าง ๆ': 173,
#  'ต้ม': 174,
#  'ต้มยำ': 175,
#  'ต้องการ': 176,
#  'ต้องอาราม': 177,
#  'ถนนใหญ่': 178,
#  'ถั่ว': 179,
#  'ถาด': 180,
#  'ถามราคา': 181,
#  'ถูกหวย': 182,
#  'ถูกใจมาก': 183,
#  'ถ่ายรูปมา': 184,
#  'ถ้วย': 185,
#  'ทดแทน': 186,
#  'ทอด': 187,
#  'ทอดมา': 188,
#  'ทอน': 189,
#  'ทะยอย': 190,
#  'ทั่วถึง': 191,
#  'ทางเข้าหน้า': 192,
#  'ทาน': 193,
#  'ทานบ่อยๆ': 194,
#  'ทานพวก': 195,
#  'ทานมาก': 196,
#  'ทานวัน': 197,
#  'ทานวันนี้': 198,
#  'ทานอาหาร': 199,
#  'ทำ': 200,
#  'ทำงานมาก': 201,
#  'ทิ้ง': 202,
#  'ที่จะ': 203,
#  'ที่ทาง': 204,
#  'ที่นั่ง': 205,
#  'ที่ไหนได้': 206,
#  'ท่าน': 207,
#  'ธรรมดา': 208,
#  'ธรรมดาด้วย': 209,
#  'น': 210,
#  'นพ': 211,
#  'นม': 212,
#  'นะคะ': 213,
#  'นัด': 214,
#  'นั่ง': 215,
#  'นาที': 216,
#  'นานก็': 217,
#  'นานมาก': 218,
#  'นาราย': 219,
#  'นิดนึง': 220,
#  'นิวออ': 221,
#  'นึก': 222,
#  'นึกถึง': 223,
#  'นึง': 224,
#  'นุ่ม': 225,
#  'น่ารัก': 226,
#  'น้ำ': 227,
#  'น้ำจิ้ม': 228,
#  'น้ำชาบู': 229,
#  'น้ำดื่ม': 230,
#  'น้ำมัน': 231,
#  'บ': 232,
#  'บด': 233,
#  'บรา': 234,
#  'บริการ': 235,
#  'บริเวณ': 236,
#  'บอ': 237,
#  'บอกอยู่แล้ว': 238,
#  'บัตรสมาชิก': 239,
#  'บางกะปิ': 240,
#  'บางรายการ': 241,
#  'บางส่วน': 242,
#  'บาท': 243,
#  'บาร์': 244,
#  'บุ': 245,
#  'บุพ': 246,
#  'บุฟเฟต์': 247,
#  'บุฟเฟ่ต์': 248,
#  'บูต': 249,
#  'บ๊วย': 250,
#  'บ๋ว': 251,
#  'ป': 252,
#  'ปรกติ': 253,
#  'ประ': 254,
#  'ประกอบกับ': 255,
#  'ประตู': 256,
#  'ประทับใจ': 257,
#  'ปรับปรุงดีขึ้น': 258,
#  'ปรุง': 259,
#  'ปลา': 260,
#  'ปลาดิบ': 261,
#  'ปอกเปลือก': 262,
#  'ปิดท้าย': 263,
#  'ปุ': 264,
#  'ปุระ': 265,
#  'ปูอัด': 266,
#  'ผัก': 267,
#  'ผิดหวัง': 268,
#  'ผ่านพนักงาน': 269,
#  'ผ่านระบบ': 270,
#  'ฝรั่ง': 271,
#  'ฝั่ง': 272,
#  'พนักงาน': 273,
#  'พนักงานขยัน': 274,
#  'พนักงานค่ะ': 275,
#  'พนักงานบริการดี': 276,
#  'พระราม': 277,
#  'พรีเมียม': 278,
#  'พลาด': 279,
#  'พอน': 280,
#  'พอได้ที่นั่ง': 281,
#  'พารา': 282,
#  'พาราไดซ์': 283,
#  'พิซ': 284,
#  'พิซซ่า': 285,
#  'พี่': 286,
#  'ฟรี': 287,
#  'ฟู้ด': 288,
#  'ฟเฟ': 289,
#  'ฟเฟ่': 290,
#  'ภาษา': 291,
#  'ม': 292,
#  'มอ': 293,
#  'มอลล์': 294,
#  'มะนาว': 295,
#  'มันดี': 296,
#  'มากก': 297,
#  'มากขึ้น': 298,
#  'มากค่ะ': 299,
#  'มากนัก': 300,
#  'มากับ': 301,
#  'มากินที่': 302,
#  'มาก่อน': 303,
#  'มาด้วย': 304,
#  'มาตรา': 305,
#  'มานที่': 306,
#  'มานิดๆ': 307,
#  'มาบางมาก': 308,
#  'มาสามรส': 309,
#  'มีค่าน้ำ': 310,
#  'มีชื่อ': 311,
#  'มีตัวเลือก': 312,
#  'มีน้ำ': 313,
#  'มีน้ำชาเขียว': 314,
#  'มีโอกาสมาทานก่อนร้าน': 315,
#  'มี่': 316,
#  'มื้อ': 317,
#  'มุ': 318,
#  'ยม': 319,
#  'ยอ': 320,
#  'ยอด': 321,
#  'ยังมี': 322,
#  'ยากค่ะ': 323,
#  'ยุค': 324,
#  'รส': 325,
#  'รสชาติ': 326,
#  'รสชาติกรุบ': 327,
#  'รสชาติดี': 328,
#  'รสชาติดีนะ': 329,
#  'รสชาติดีมาก': 330,
#  'รสชาติดีมากคุ้มค่า': 331,
#  'รสชาติธรรมดา': 332,
#  'รอ': 333,
#  'รอบ': 334,
#  'รอบนี้': 335,
#  'ระดับ': 336,
#  'รับประกัน': 337,
#  'ราคา': 338,
#  'ราคาตาม': 339,
#  'ราคานี้': 340,
#  'ราคาบุฟเฟ่ต์': 341,
#  'ราคามี': 342,
#  'ราคาสามร้อย': 343,
#  'รายละเอียด': 344,
#  'รีฟี': 345,
#  'รี่': 346,
#  'รู้จักร้าน': 347,
#  'รู้สึก': 348,
#  'ร่อย': 349,
#  'ร้อน': 350,
#  'ร้านกว้างขวาง': 351,
#  'ร้านก็': 352,
#  'ร้านทั่วไป': 353,
#  'ร้านที่': 354,
#  'ร้านบุ': 355,
#  'ร้านบุฟเฟ่ต์': 356,
#  'ร้านมี': 357,
#  'ร้านอยู่': 358,
#  'ร้านอาหารบุ': 359,
#  'ล': 360,
#  'ลงเอย': 361,
#  'ลด': 362,
#  'ลบ': 363,
#  'ลอง': 364,
#  'ลอตเตอรี่': 365,
#  'ละลานตามาก': 366,
#  'ลา': 367,
#  'ลาขาด': 368,
#  'ลาน': 369,
#  'ลิ้น': 370,
#  'ลี': 371,
#  'ลืม': 372,
#  'ลุย': 373,
#  'ลูก': 374,
#  'ลูกค้า': 375,
#  'ลูกชิ้น': 376,
#  'วก': 377,
#  'วน': 378,
#  'ววว': 379,
#  'วันก่อน': 380,
#  'วันหยุด': 381,
#  'วาง': 382,
#  'วานิลา': 383,
#  'วิป': 384,
#  'ว่าน้อย': 385,
#  'ส': 386,
#  'สด': 387,
#  'สดกว่า': 388,
#  'สดๆ ร้อนๆ': 389,
#  'สตอ': 390,
#  'สบายดี': 391,
#  'สปาเกตตี': 392,
#  'สมราคา': 393,
#  'สมา': 394,
#  'สมใจ': 395,
#  'สรุป': 396,
#  'สลัด': 397,
#  'สวย': 398,
#  'สวัสดี': 399,
#  'สะอาด': 400,
#  'สะอาดสะอ้าน': 401,
#  'สัน': 402,
#  'สัปดาห์': 403,
#  'สั่ง': 404,
#  'สาขา': 405,
#  'สาขานี้': 406,
#  'สาขายู': 407,
#  'สาย': 408,
#  'สายพาน': 409,
#  'สายพานก็': 410,
#  'สายพานที่': 411,
#  'สายพานยาว': 412,
#  'สายพานร้านอื่นๆ': 413,
#  'สายพานออก': 414,
#  'สาเหตุ': 415,
#  'สำหรับ': 416,
#  'สุกก็': 417,
#  'สุกี้': 418,
#  'สุกี้ยากี้': 419,
#  'สุดท้าย': 420,
#  'สู้': 421,
#  'สไตล์': 422,
#  'สไปรท์': 423,
#  'สไลด์': 424,
#  'ส่วนตัว': 425,
#  'ส์': 426,
#  'ห': 427,
#  'หนา': 428,
#  'หนึบ': 429,
#  'หน่อยมี': 430,
#  'หน้า': 431,
#  'หมู': 432,
#  'หมู่คณะ': 433,
#  'หม้อ': 434,
#  'หยิบ': 435,
#  'หลังจากที่': 436,
#  'หลากรส': 437,
#  'หลากหลาย': 438,
#  'หลากหลายชนิด': 439,
#  'หลายครั้ง': 440,
#  'หล่ะ': 441,
#  'หวย': 442,
#  'หวาน': 443,
#  'หอม': 444,
#  'หอมมาก': 445,
#  'หอย': 446,
#  'หัว': 447,
#  'หา': 448,
#  'หาไม่': 449,
#  'หิว': 450,
#  'ห่างหาย': 451,
#  'ห้าง': 452,
#  'ห้างมักจะ': 453,
#  'อ': 454,
#  'อง': 455,
#  'อป': 456,
#  'อม': 457,
#  'อย': 458,
#  'อยากได้': 459,
#  'อยู่แล้ว': 460,
#  'อย่า': 461,
#  'อย่างอื่น': 462,
#  'อย่างอื่นๆ': 463,
#  'อร่อย': 464,
#  'อลล์': 465,
#  'ออ': 466,
#  'ออกมา': 467,
#  'ออกร้าน': 468,
#  'ออร์เดอร์': 469,
#  'ออสเตรเลีย': 470,
#  'อันนี้': 471,
#  'อัพเดท': 472,
#  'อาทิตย์': 473,
#  'อาหาร': 474,
#  'อาหารก็': 475,
#  'อาหารทาน': 476,
#  'อาหารที่': 477,
#  'อาหารบน': 478,
#  'อาหารบุฟเฟ่ต์': 479,
#  'อาหารสด': 480,
#  'อาหารอันนี้': 481,
#  'อาหารอื่นๆ': 482,
#  'อาหารเสริม': 483,
#  'อิอิ': 484,
#  'อิ่ม': 485,
#  'อีกครั้ง': 486,
#  'อีกนิดหน่อย': 487,
#  'อีกมากมาย': 488,
#  'อีกหนึ่ง': 489,
#  'อีกอย่าง': 490,
#  'ฮัน': 491,
#  'ฮ่า': 492,
#  'ะ': 493,
#  'ะปิ)': 494,
#  'ัล': 495,
#  'า': 496,
#  'ิ': 497,
#  'ีย': 498,
#  'ี่+': 499,
#  'ุ': 500,
#  'ุ่': 501,
#  'เ': 502,
#  'เกินไป': 503,
#  'เกี๊ยว': 504,
#  'เก้': 505,
#  'เข้มข้น': 506,
#  'เข้ากัน': 507,
#  'เคยกิน': 508,
#  'เคยลอง': 509,
#  'เครือ': 510,
#  'เครื่องดื่ม': 511,
#  'เคลม': 512,
#  'เคลื่อนตัว': 513,
#  'เคาน์เตอร์': 514,
#  'เค็ม': 515,
#  'เค้า': 516,
#  'เงิน': 517,
#  'เงินสดนะ': 518,
#  'เจอ': 519,
#  'เช็คบิล': 520,
#  'เช็คบิลด้วย': 521,
#  'เซ': 522,
#  'เซต': 523,
#  'เซ็ท': 524,
#  'เดอะ': 525,
#  'เดิน': 526,
#  'เดียวกันได้': 527,
#  'เด็ก': 528,
#  'เด็ด': 529,
#  'เด่นมาก': 530,
#  'เด้ง': 531,
#  'เด้งดี': 532,
#  'เติม': 533,
#  'เต็ม': 534,
#  'เต้าเจี้ยว': 535,
#  'เท': 536,
#  'เทียบ': 537,
#  'เนื้อ': 538,
#  'เนื้อวัว': 539,
#  'เนื้อสัตว์': 540,
#  'เนื้อหมู': 541,
#  'เบ': 542,
#  'เบคอน': 543,
#  'เบอร์รี่': 544,
#  'เบา': 545,
#  'เปรี้ยวหวาน': 546,
#  'เป็ด': 547,
#  'เป็นกันเอง': 548,
#  'เป็นปกติ': 549,
#  'เป็นผู้ใหญ่': 550,
#  'เป็นหลัก': 551,
#  'เป็นแนว': 552,
#  'เผ็ด': 553,
#  'เพลิน': 554,
#  'เพื่อน': 555,
#  'เฟรนไชส์': 556,
#  'เฟ่': 557,
#  'เมนู': 558,
#  'เย็นชื่นใจ': 559,
#  'เร': 560,
#  'เรย': 561,
#  'เรียด': 562,
#  'เรื่อง': 563,
#  'เลิก': 564,
#  'เลี่ยน': 565,
#  'เลือก': 566,
#  'เล่น': 567,
#  'เวลา': 568,
#  'เสาร์': 569,
#  'เสิร์ฟ': 570,
#  'เส้น': 571,
#  'เหนียว': 572,
#  'เหมาะสม': 573,
#  'เหมือนกัน': 574,
#  'เหมือนกับ': 575,
#  'เหมือนกุ้ง': 576,
#  'เหลือกุ้ง': 577,
#  'เหวี่ยง': 578,
#  'เห็ด': 579,
#  'แ': 580,
#  'แกงค์': 581,
#  'แกงเขียวหวาน': 582,
#  'แก้ว': 583,
#  'แคบ': 584,
#  'แจ้ง': 585,
#  'แดง': 586,
#  'แตกต่างกัน': 587,
#  'แต่วันนี้': 588,
#  'แต่เพียงพอกับ': 589,
#  'แถม': 590,
#  'แถมลด': 591,
#  'แนว': 592,
#  'แนะนำ': 593,
#  'แน่น': 594,
#  'แน่นอน': 595,
#  'แน่นอนครับ': 596,
#  'แบบฉบับ': 597,
#  'แบบที่': 598,
#  'แบบนี้': 599,
#  'แบ่ง': 600,
#  'แปลกหน่อย': 601,
#  'แปลกใหม่': 602,
#  'แป้ง': 603,
#  'แพง': 604,
#  'แพงมั้ย': 605,
#  'แฟน': 606,
#  'แมค': 607,
#  'แย่': 608,
#  'แย้': 609,
#  'แล': 610,
#  'แลก': 611,
#  'แล้วก็': 612,
#  'แล้วตัก': 613,
#  'แล้วรู้สึก': 614,
#  'แวะ': 615,
#  'แออัด': 616,
#  'โก': 617,
#  'โควิด': 618,
#  'โชคชะตา': 619,
#  'โชคดี': 620,
#  'โชคดีมาก': 621,
#  'โชย': 622,
#  'โซน': 623,
#  'โดน': 624,
#  'โดนมา': 625,
#  'โดยการกด': 626,
#  'โดยประมาณ': 627,
#  'โดยรวม': 628,
#  'โดยเฉพาะ': 629,
#  'โต๊ะ': 630,
#  'โทส': 631,
#  'โน้น': 632,
#  'โปรบัตรเครดิต': 633,
#  'โปรมา': 634,
#  'โปรโมชั่น': 635,
#  'โฟลต': 636,
#  'โม': 637,
#  'โมจิ': 638,
#  'โม่': 639,
#  'โร': 640,
#  'โหด': 641,
#  'โอ': 642,
#  'โออิชิ': 643,
#  'โอเค': 644,
#  'ใช้แล้วอยู่': 645,
#  'ใช้ได้': 646,
#  'ใส': 647,
#  'ใส่': 648,
#  'ใส่ใจ': 649,
#  'ไก่': 650,
#  'ไข่': 651,
#  'ไข่ไก่': 652,
#  'ได': 653,
#  'ไดฟูกุ': 654,
#  'ได้กลิ่น': 655,
#  'ได้ช่อง': 656,
#  'ได้ยิน': 657,
#  'ได้เวลา': 658,
#  'ไทย': 659,
#  'ไปยืน': 660,
#  'ไผ่': 661,
#  'ไม่ค่อยมาก': 662,
#  'ไม่ค่อยมี': 663,
#  'ไม่งั้น': 664,
#  'ไม่ต้องออก': 665,
#  'ไม้': 666,
#  'ไลน์': 667,
#  'ไว': 668,
#  'ไหว': 669,
#  'ไอติม': 670,
#  'ไอติมกับ': 671,
#  'ไอติมก็': 672,
#  'ไอศกรีม': 673,
#  'ไอศกรีมรส': 674,
#  'ไอศครีม': 675,
#  'ๆ)': 676,
#  '้': 677,
#  '้วย': 678,
#  '้ะ': 679,
#  '–': 680}

# %% [markdown]
# ## **Create Dictionary**

# %%
documents = df['Review_tokenized'].to_list()
texts = [[text for text in doc.split(',')] for doc in documents]
dictionary = gensim.corpora.Dictionary(texts)

# %%
print(dictionary.token2id.keys())
# Out:
# dict_keys(['การบริการรสชาติ', 'กิน', 'ของอาหาร', 'ข้างนอก', 'ความต้องการ', 'คอ', 'คุณภาพ', 'คุณภาพดี', 'คุ้ม', 'จำกัด', 'ซุป', 'ดำ', 'ดีมาก', 'ถาด', 'ถามราคา', 'น่ารัก', 'น้ำ', 'น้ำจิ้ม', 'บริการ', 'บาท', 'ประทับใจ', 'พนักงาน', 'มาก่อน', 'รสชาติ', 'รสชาติดีนะ', 'สรุป', 'สะอาดสะอ้าน', 'สัน', 'หลากหลาย', 'อร่อย', 'อาหาร', 'อาหารอันนี้', 'เคยกิน', 'เคลม', 'เซ็ท', 'เต้าเจี้ยว', 'เนื้อ', 'เป็ด', 'เผ็ด', 'แต่เพียงพอกับ', 'แบบนี้', 'แปลกใหม่', 'แฟน', 'โดยรวม', 'โมจิ', 'ใส่ใจ', 'ไม่ต้องออก', 'ไอติมก็', 'CTW', 'Terminal', 'การงดรับ', 'การบริการก็', 'คิดถึง', 'ชาบู', 'ญี่ปุ่น', 'ฐาน', 'ดี', 'ทะยอย', 'ทำงานมาก', 'ที่ทาง', 'นาที', 'นึกถึง', 'พนักงานบริการดี', 'พระราม', 'พรีเมียม', 'พาราไดซ์', 'มาตรา', 'มีโอกาสมาทานก่อนร้าน', 'รายละเอียด', 'ร้านก็', 'ลูกค้า', 'สาขา', 'สาขานี้', 'สู้', 'ออร์เดอร์', 'เครื่องดื่ม', 'เค้า', 'เจอ', 'เป็นกันเอง', 'เหวี่ยง', 'แจ้ง', 'โม', 'โม่', 'โอเค', 'กั้น', 'ของหวาน', 'คนละ', 'คาว', 'คุ', 'คุ้มค่า', 'จาน', 'จิ้ม', 'จืด', 'ฉาก', 'ชอบ', 'ชาเขียว', 'ชิ้น', 'ซอย', 'ซอส', 'ตก', 'ตัก', 'ตา', 'ตามน้ำ', 'ถั่ว', 'ถ่ายรูปมา', 'ทาน', 'ทานบ่อยๆ', 'นั่ง', 'นุ่ม', 'บด', 'บอ', 'บาร์', 'บูต', 'ผัก', 'ภาษา', 'มากก', 'มากับ', 'มาสามรส', 'มีชื่อ', 'ยังมี', 'รส', 'รสชาติกรุบ', 'ราคา', 'รี่', 'รู้สึก', 'ลอง', 'ลิ้น', 'ลืม', 'ววว', 'สด', 'สตอ', 'สั่ง', 'ส่วนตัว', 'หนึบ', 'หม้อ', 'หวาน', 'อยากได้', 'ะ', 'เ', 'เข้มข้น', 'เข้ากัน', 'เค็ม', 'เดียวกันได้', 'เนื้อวัว', 'เนื้อสัตว์', 'เนื้อหมู', 'เป็นผู้ใหญ่', 'เลือก', 'เสิร์ฟ', 'เหนียว', 'เห็ด', 'แ', 'แดง', 'แตกต่างกัน', 'แนว', 'แย้', 'โควิด', 'โต๊ะ', 'โร', 'ใส', 'ไก่', 'ไข่', 'ไดฟูกุ', 'ไผ่', 'ไม้', 'ไหว', 'ไอติม', 'ไอติมกับ', 'ข้าว', 'จ่าย', 'ชาบูที่', 'ถ้วย', 'ทานมาก', 'ธรรมดาด้วย', 'ส', 'ออ', 'อีกอย่าง', 'เกินไป', 'เลี่ยน', 'โปรมา', 'โหด', 'ไว', 'ไอศกรีมรส', 'ขนมอร่อย', 'ตัดสินใจ', 'ต่าง ๆ', 'ที่จะ', 'ที่นั่ง', 'น้ำชาบู', 'ประกอบกับ', 'มาด้วย', 'ลูกชิ้น', 'สบายดี', 'หน้า', 'หอมมาก', 'เดิน', 'เด็ก', 'เส้น', 'เหมือนกับ', 'แคบ', 'โปรบัตรเครดิต', 'ได้กลิ่น', 'ซึ', 'นะคะ', 'บ๋ว', 'ผ่านพนักงาน', 'พอน', 'ฟเฟ่', 'มากค่ะ', 'ยอ', 'ราคามี', 'ร่อย', 'ร้านบุ', 'ร้านมี', 'สาย', 'หยิบ', 'โซน', 'โปรโมชั่น', 'Menu', 'Number', 'กรรมวิธี', 'ก์', 'คน', 'คะแนน', 'งก', 'ชุด', 'ดังเดิม', 'บุฟเฟ่ต์', 'ประ', 'พารา', 'มอ', 'ยุค', 'ร้านอาหารบุ', 'ลบ', 'สุกี้', 'สไตล์', 'ส์', 'หมู', 'หลากหลายชนิด', 'ะปิ)', 'า', 'เดอะ', 'เมนู', 'แบบฉบับ', 'แบ่ง', 'ได', 'ไทย', '–', 'กาแฟ', 'ของการกิน', 'คอก็', 'งวด', 'ตอนที่', 'ตำ', 'ติด', 'น', 'บ๊วย', 'มีน้ำชาเขียว', 'รสชาติดีมาก', 'รสชาติดีมากคุ้มค่า', 'ร้อน', 'ร้านทั่วไป', 'ลุย', 'สุกี้ยากี้', 'อยู่แล้ว', 'ออสเตรเลีย', 'ุ', 'เป็นปกติ', 'เฟรนไชส์', 'เรื่อง', 'เหมาะสม', 'แนะนำ', 'โชย', 'ไข่ไก่', 'ไม่ค่อยมี', 'ไอศครีม', 'กุ้ง', 'ของกิน', 'ขาบูชิต', 'ซูชิ', 'ซ่า', 'ตอน', 'ตอนนี้', 'นิดนึง', 'ปุระ', 'ปูอัด', 'ม', 'มานที่', 'ละลานตามาก', 'สายพาน', 'หิว', 'อง', 'อาหารทาน', 'อาหารบน', 'ฮ่า', 'เกี๊ยว', 'เท', 'เทียบ', 'เล่น', 'แพงมั้ย', 'แล้วก็', 'ไม่งั้น', '้', 'กลายเป็นมา', 'กี่', 'ชั่วคราวน', 'ชิ', 'ซะงั้น', 'ญี่', 'ดึก', 'ตบท้าย', 'ตัว', 'ทอด', 'ทานอาหาร', 'นพ', 'นานก็', 'นึก', 'ปลา', 'ปุ', 'ผิดหวัง', 'วก', 'สมใจ', 'หน่อยมี', 'อย่า', 'อาหารเสริม', 'เติม', 'เป็นหลัก', 'เย็นชื่นใจ', 'เหลือกุ้ง', 'ไม่ค่อยมาก', '้ะ', 'net', 'กลับมา', 'ของคาว', 'ชม.', 'ซูชิลายตามาก', 'ตรงนั้น', 'สไลด์', 'อัพเดท', 'อิ่ม', 'เบ', 'เพลิน', 'ไปยืน', 'ไลน์', 'G', 'Net', 'Shabushi', 'กรอบดี', 'ของบน', 'ของหวานที่', 'ขาดสารอาหาร', 'ขึ้นราคา', 'ข่าว', 'คนเดียว', 'ครึ่ง', 'คิว', 'คุณภาพอาหารดู', 'งาน', 'จุ', 'ชั่วโมง', 'ชั้น', 'ชื่นใจดี', 'ดู', 'ตลับ', 'ตับ', 'ตั้งอยู่', 'ตั้งใจมากิน', 'ติง', 'ติดมัน', 'ถนนใหญ่', 'ถูกใจมาก', 'ทอดมา', 'ทานวันนี้', 'ทำ', 'ทิ้ง', 'ธรรมดา', 'นานมาก', 'น้ำมัน', 'บางกะปิ', 'บางรายการ', 'ปลาดิบ', 'ปอกเปลือก', 'ฝรั่ง', 'ฝั่ง', 'พนักงานค่ะ', 'มอลล์', 'มานิดๆ', 'มาบางมาก', 'มื้อ', 'ยากค่ะ', 'รสชาติธรรมดา', 'รอ', 'ระดับ', 'ราคาบุฟเฟ่ต์', 'ร้านกว้างขวาง', 'ลาขาด', 'ลูก', 'วันหยุด', 'วาง', 'วานิลา', 'ว่าน้อย', 'สะอาด', 'สายพานออก', 'สาเหตุ', 'สำหรับ', 'สไปรท์', 'หนา', 'หอม', 'หอย', 'หาไม่', 'ห่างหาย', 'ห้าง', 'อม', 'ออกมา', 'อาทิตย์', 'อาหารที่', 'อีกครั้ง', 'อีกหนึ่ง', 'เช็คบิล', 'เช็คบิลด้ว ...

# %%
gensim_corpus = [dictionary.doc2bow(text, allow_update=True) for text in texts]
word_frequencies = [[(dictionary[id], frequence) for id, frequence in couple] for couple in gensim_corpus]

# %% [markdown]
# ## **Topic Modeling**

# %%
num_topics = 7
chunksize = 4000 # size of the doc looked at every pass
passes = 20 # number of passes through documents
iterations = 50
eval_every = 1  # Don't evaluate model perplexity, takes too much time.

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

# %time model = gensim.models.LdaModel(corpus=gensim_corpus, id2word=id2word, chunksize=chunksize, \
                       alpha='auto', eta='auto', \
                       iterations=iterations, num_topics=num_topics, \
                       passes=passes, eval_every=eval_every)
# Out:
# CPU times: user 353 ms, sys: 1.26 ms, total: 354 ms
# Wall time: 353 ms

# %%
gensimvis.prepare(model, gensim_corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.060349  0.061770       1        1  22.629114
# 3      0.082110  0.020330       2        1  22.247675
# 1     -0.038898 -0.055697       3        1  17.236425
# 0      0.014301 -0.012845       4        1  13.349130
# 5     -0.001451 -0.011175       5        1  10.389959
# 6     -0.003105 -0.007340       6        1   9.756073
# 4      0.007392  0.004957       7        1   4.391624, topic_info=      Term       Freq      Total Category  logprob  loglift
# 286      ม   5.000000   5.000000  Default  30.0000  30.0000
# 296     เท   5.000000   5.000000  Default  29.0000  29.0000
# 284   ปุระ   5.000000   5.000000  Default  28.0000  28.0000
# 105    ทาน  16.000000  16.000000  Default  27.0000  27.0000
# 276   กุ้ง   8.000000   8.000000  Default  26.0000  26.0000
# ..     ...        ...        ...      ...      ...      ...
# 29   อร่อย   0.439178  16.213535   Topic7  -4.8528  -0.4832
# 122   ราคา   0.377767  10.163589   Topic7  -5.0034  -0.1668
# 127    ลืม   0.266320   1.936509   Topic7  -5.3530   1.1415
# 311    ตัว   0.293695   3.424576   Topic7  -5.2551   0.6693
# 131   สั่ง   0.276053   9.011983   Topic7  -5.3171  -0.3602
#
# [458 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 344       2  0.353865        G
# 344       4  0.353865        G
# 591       3  0.613108      VAT
# 647       1  0.859931       กก
# 332       2  0.559177   กลับมา
# ...     ...       ...      ...
# 166       2  0.170385    ไอติม
# 166       3  0.170385    ไอติม
# 166       5  0.170385    ไอติม
# 448       2  0.539187  ไอศกรีม
# 302       6  0.661356        ้
#
# [415 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 4, 2, 1, 6, 7, 5])

# %%
model.show_topic(3)
# Out:
# [('กิน', 0.018235166),
#  ('คน', 0.017517371),
#  ('สด', 0.015160775),
#  ('กุ้ง', 0.014137382),
#  ('เวลา', 0.012140035),
#  ('อร่อย', 0.011988626),
#  ('ทาน', 0.011816798),
#  ('เนื้อ', 0.011626075),
#  ('น้ำ', 0.010787498),
#  ('ชาบู', 0.010177504)]

# %%
df['topics'] = df['Review_tokenized'].apply(lambda x: model.get_document_topics(dictionary.doc2bow(x.split(',')))[0][0])
df['score'] = df['Review_tokenized'].apply(lambda x: model.get_document_topics(dictionary.doc2bow(x.split(',')))[0][1])

# %%
df[['Restaurant', 'Review', 'topics']]
# Out:
#                                            Restaurant  ... topics
# 0   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      1
# 1   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      5
# 2   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      2
# 3   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      1
# 4   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      1
# 5   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      2
# 6   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      2
# 7   Mo-Mo-Paradise (โม โม พาราไดซ์) เดอะมอลล์ บางกะปิ  ...      6
# 8           Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      6
# 9           Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      4
# 10          Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      0
# 11          Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      3
# 12          Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      3
# 13          Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      0
# 14          Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      3
# 15          Shabushi (ชาบูชิ) เดอะมอลล์บางกะปิ ชั้น G  ...      5
# 16                                      ข้าน้อยขอชาบู  ...      0
# 17                                      ข้าน้อยขอชาบู  ...      1
# 18                                      ข้าน้อยขอชาบู  ...      6
# 19                                      ข้าน้อยขอชาบู  ...      2
# 20                                      ข้าน้อยขอชาบู  ...      1
#
# [21 rows x 3 columns]
